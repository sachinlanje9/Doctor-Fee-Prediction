# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("./raw_practo.csv")
df.head()
# Out:
#                    Name              Speciality Degree  \
# 0  Ms. Priyanka Wincy R  Dietitian/Nutritionist  B.Sc.
# 1     Ms. Neha Ranglani  Dietitian/Nutritionist  B.Sc.
# 2     Ms. Sonal Bhosale  Dietitian/Nutritionist  B.Sc.
# 3     Ms. Silky Mahajan  Dietitian/Nutritionist  B.Sc.
# 4  Ms. Twincy Ann Sunil  Dietitian/Nutritionist  B.Sc.
#
#                                   Year_of_experience  \
# 0                         4 Years Experience Overall
# 1  14 Years Experience Overall  (13 years as spec...
# 2  16 Years Experience Overall  (10 years as spec...
# 3                        15 Years Experience Overall
# 4                          1 Year Experience Overall
#
#                          Location       City dp_score          npv  \
# 0  Koramangala 7 Block, Bangalore  Bangalore     100%   (40 votes)
# 1             Bandra West, Mumbai     Mumbai      96%  (222 votes)
# 2          Kandivali West, Mumbai     Mumbai      99%   (96 votes)
# ...

# %%
df.shape
# Out:
# (6001, 9)

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5995 entries, 0 to 6000
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                5995 non-null   object
#  1   Speciality          5995 non-null   object
#  2   Degree              5995 non-null   object
#  3   Year_of_experience  5995 non-null   object
#  4   Location            5995 non-null   object
#  5   City                5995 non-null   object
#  6   dp_score            5995 non-null   object
#  7   npv                 5995 non-null   object
#  8   consultation_fee    5995 non-null   object
# dtypes: object(9)
# memory usage: 468.4+ KB

# %%
for i in df:
    print(i)
    print(df[i].nunique())
    print(df[i].unique())
# Out:
# Name
# 5548
# ['Ms. Priyanka Wincy R' 'Ms. Neha Ranglani' 'Ms. Sonal Bhosale' ...
#  'Ms. Shweta Uchil' 'Ms. Pallavi Larecha' 'Ms. Ushma Haria']
# Speciality
# 19
# ['Dietitian/Nutritionist' 'Dentist' 'Physiotherapist' 'Chiropractor'
#  'Dermatologist' 'Gynecologist' 'Infertility Specialist' 'Pediatrician'
#  'Orthopedist' 'Pulmonologist' 'Cardiologist' 'Rheumatologist'
#  'Gastroenterologist' 'Neurologist' 'Bariatric Surgeon' 'Urologist'
#  'Neurosurgeon' 'Ophthalmologist' 'Psychiatrist']
# Degree
# 849
# ['B.Sc.' 'BAMS' 'BDS' 'MDS' 'PhD - Orthodontics' 'BHMS' 'BNYS' 'BPTh/BPT'
#  'MPTh/MPT' 'MPT/MPTh' 'BSc - Dietitics / Nutrition'
#  'MSc - Applied Nutrition' 'BSc - Physiotherapy'
#  'BSc. - Applied Nutrition' 'DDVL, MBBS' 'DGO'
#  'DNB - Obstetrics & Gynecology' 'MD - Obstetrics & Gynaecology'
#  'DGO, MBBS' 'Diploma in Child Health (DCH), MBBS'
#  'Diploma in Diet and Nutrition' 'MBBS' 'DDPHN' 'DDHN'
#  'Diploma in Physiotherapy'
# ...

# %%
df['Year_of_experience']=df['Year_of_experience'].replace('[^0-9]',' ',regex=True).\
str.strip().str.split(expand=True)[0].astype(float)

# %%
df['npv']=df['npv'].replace("[^0-9]",'',regex=True).astype(int)

# %%
df['consultation_fee']=df['consultation_fee'].replace("[^0-9]",'',regex=True).astype(int)

# %%
df['dp_score']=df['dp_score'].replace("[^0-9]",'',regex=True).astype(int)

# %%
df.head()
# Out:
#                    Name              Speciality Degree  Year_of_experience  \
# 0  Ms. Priyanka Wincy R  Dietitian/Nutritionist  B.Sc.                 4.0
# 1     Ms. Neha Ranglani  Dietitian/Nutritionist  B.Sc.                14.0
# 2     Ms. Sonal Bhosale  Dietitian/Nutritionist  B.Sc.                16.0
# 3     Ms. Silky Mahajan  Dietitian/Nutritionist  B.Sc.                15.0
# 4  Ms. Twincy Ann Sunil  Dietitian/Nutritionist  B.Sc.                 1.0
#
#                          Location       City  dp_score  npv  consultation_fee
# 0  Koramangala 7 Block, Bangalore  Bangalore       100   40               600
# 1             Bandra West, Mumbai     Mumbai        96  222              2500
# 2          Kandivali West, Mumbai     Mumbai        99   96                 0
# 3  Koramangala 3 Block, Bangalore  Bangalore        97  270              1770
# 4  Koramangala 5 Block, Bangalore  Bangalore        99  121               600

# %%
df[['Location', 'ABC']] = df['Location'].str.split(',', expand=True)

# %%
df.drop('ABC',axis=1,inplace=True)

# %%
df.head()
# Out:
#                    Name              Speciality Degree  Year_of_experience  \
# 0  Ms. Priyanka Wincy R  Dietitian/Nutritionist  B.Sc.                 4.0
# 1     Ms. Neha Ranglani  Dietitian/Nutritionist  B.Sc.                14.0
# 2     Ms. Sonal Bhosale  Dietitian/Nutritionist  B.Sc.                16.0
# 3     Ms. Silky Mahajan  Dietitian/Nutritionist  B.Sc.                15.0
# 4  Ms. Twincy Ann Sunil  Dietitian/Nutritionist  B.Sc.                 1.0
#
#               Location       City  dp_score  npv  consultation_fee
# 0  Koramangala 7 Block  Bangalore       100   40               600
# 1          Bandra West     Mumbai        96  222              2500
# 2       Kandivali West     Mumbai        99   96                 0
# 3  Koramangala 3 Block  Bangalore        97  270              1770
# 4  Koramangala 5 Block  Bangalore        99  121               600

# %%
df['Year_of_experience'].isna().sum()
# Out:
# 2

# %%
df=df.dropna()

# %%
df['Year_of_experience']=df['Year_of_experience'].astype(int)

# %%
df.dtypes
# Out:
# Name                  object
# Speciality            object
# Degree                object
# Year_of_experience     int32
# Location              object
# City                  object
# dp_score               int32
# npv                    int32
# consultation_fee       int32
# dtype: object

# %%
df['npv(votes)']=df['npv']

# %%
df.drop('npv',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#                    Name              Speciality Degree  Year_of_experience  \
# 0  Ms. Priyanka Wincy R  Dietitian/Nutritionist  B.Sc.                   4
# 1     Ms. Neha Ranglani  Dietitian/Nutritionist  B.Sc.                  14
#
#               Location       City  dp_score  consultation_fee  npv(votes)
# 0  Koramangala 7 Block  Bangalore       100               600          40
# 1          Bandra West     Mumbai        96              2500         222

# %%
df.shape
# Out:
# (5993, 9)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (5993, 9)

# %%
df['Degree_']=df['Degree'].str.split(expand=True)[0]

# %%
df['Degree_']=df['Degree_'].str.replace("[^a-zA-Z/]",'',regex=True)

# %%
df['Degree_'].unique()
# Out:
# array(['BSc', 'BAMS', 'BDS', 'MDS', 'PhD', 'BHMS', 'BNYS', 'BPTh/BPT',
#        'MPTh/MPT', 'MPT/MPTh', 'MSc', 'DDVL', 'DGO', 'DNB', 'MD',
#        'Diploma', 'MBBS', 'DDPHN', 'DDHN', 'DM', 'DNHE', 'DO', 'Doctor',
#        'Doctorate', 'DOMS', 'DPM', 'DVD', 'FCPS', 'Fellow', 'Fellowship',
#        'FNB', 'FRCP', 'FRCS', 'Masters', 'MCh', 'Member', 'MRCOGUK',
#        'MRCS', 'MS', 'PG', 'PGD', 'Post'], dtype=object)

# %%
df['Degree_'].replace('DO','Doctorate',inplace=True)
df['Degree_'].replace('Doctor','Doctorate',inplace=True)
df['Degree_'].replace('Post','PG',inplace=True)

# %%
remove = ['FNB', 'Fellow', 'DVD', 'Member', 'MRCOGUK', 'MRCS', 'DNHE','Fellowship','Masters']
df = df[~df['Degree_'].isin(remove)]

# %%
# df['Dgree-1'].value_counts().tail(8)

# %%
df['Degree_'].unique()
# Out:
# array(['BSc', 'BAMS', 'BDS', 'MDS', 'PhD', 'BHMS', 'BNYS', 'BPTh/BPT',
#        'MPTh/MPT', 'MPT/MPTh', 'MSc', 'DDVL', 'DGO', 'DNB', 'MD',
#        'Diploma', 'MBBS', 'DDPHN', 'DDHN', 'DM', 'Doctorate', 'DOMS',
#        'DPM', 'FCPS', 'FRCP', 'FRCS', 'MCh', 'MS', 'PG', 'PGD'],
#       dtype=object)

# %%
df.drop('Degree',axis=1,inplace=True)

# %%
df.rename(columns={'Degree_': 'Degree'}, inplace=True)

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.reset_index()
# Out:
#       index              Speciality  Year_of_experience  \
# 0         0  Dietitian/Nutritionist                   4
# 1         1  Dietitian/Nutritionist                  14
# 2         2  Dietitian/Nutritionist                  16
# 3         3  Dietitian/Nutritionist                  15
# 4         4  Dietitian/Nutritionist                   1
# ...     ...                     ...                 ...
# 5965   5996  Dietitian/Nutritionist                  17
# 5966   5997  Dietitian/Nutritionist                  26
# 5967   5998  Dietitian/Nutritionist                  24
# 5968   5999  Dietitian/Nutritionist                  13
# 5969   6000  Dietitian/Nutritionist                  14
#
#                     Location       City  dp_score  consultation_fee  \
# 0        Koramangala 7 Block  Bangalore       100               600
# 1                Bandra West     Mumbai        96              2500
# 2             Kandivali West     Mumbai        99                 0
# ...

# %%
df.dtypes
df
# Out:
#                   Speciality  Year_of_experience                Location  \
# 0     Dietitian/Nutritionist                   4     Koramangala 7 Block
# 1     Dietitian/Nutritionist                  14             Bandra West
# 2     Dietitian/Nutritionist                  16          Kandivali West
# 3     Dietitian/Nutritionist                  15     Koramangala 3 Block
# 4     Dietitian/Nutritionist                   1     Koramangala 5 Block
# ...                      ...                 ...                     ...
# 5996  Dietitian/Nutritionist                  17  Greater Kailash Part 1
# 5997  Dietitian/Nutritionist                  26          Kandivali West
# 5998  Dietitian/Nutritionist                  24          Kandivali West
# 5999  Dietitian/Nutritionist                  13           Shalimar Bagh
# 6000  Dietitian/Nutritionist                  14            Chembur East
#
#            City  dp_score  consultation_fee  npv(votes) Degree
# ...

# %%
df.to_csv('clean_practo_data.csv',index=False)

# %% [markdown]
# # EDA

# %%
df2=pd.read_csv('clean_practo_data.csv')
df2
# Out:
#                   Speciality  Year_of_experience                Location  \
# 0     Dietitian/Nutritionist                   4     Koramangala 7 Block
# 1     Dietitian/Nutritionist                  14             Bandra West
# 2     Dietitian/Nutritionist                  16          Kandivali West
# 3     Dietitian/Nutritionist                  15     Koramangala 3 Block
# 4     Dietitian/Nutritionist                   1     Koramangala 5 Block
# ...                      ...                 ...                     ...
# 5965  Dietitian/Nutritionist                  17  Greater Kailash Part 1
# 5966  Dietitian/Nutritionist                  26          Kandivali West
# 5967  Dietitian/Nutritionist                  24          Kandivali West
# 5968  Dietitian/Nutritionist                  13           Shalimar Bagh
# 5969  Dietitian/Nutritionist                  14            Chembur East
#
#            City  dp_score  consultation_fee  npv(votes) Degree
# ...

# %% [markdown]
# ## City Wise analysis of doctors

# %%
x=df2.groupby('City').agg({'Speciality':'count'}).sort_values(by='Speciality',ascending=False).reset_index()
x
# Out:
#         City  Speciality
# 0  Bangalore        2808
# 1      Delhi        1786
# 2     Mumbai        1376

# %%
cities = ['Bangalore', 'Delhi', 'Mumbai']
values = x['Speciality']

colors = ['#32CD32', '#9370DB', '#FFA500']

plt.figure(figsize=(6, 4))
bars = plt.bar(cities, values, color=colors,data=x)

#Data labels
for bar, value in zip(bars, values):
    plt.annotate(str(value), (bar.get_x() + bar.get_width() / 2, bar.get_height() + 5),
                 ha='center', va='bottom')

plt.xlabel('City')
plt.ylabel('Total Number of Doctors')
plt.title('City-wise Total Number of Doctors', y=1.02, fontsize=12,fontweight='bold')

plt.tight_layout()
plt.savefig('City-wise Total Number of Doctors.jpg', format='jpeg')
plt.show()

# %%
# Blue Shades:

# Light Blue: #ADD8E6
# Medium Blue: #6495ED
# Dark Blue: #0000CD
# Green Shades:

# Light Green: #90EE90
# Medium Green: #32CD32
# Dark Green: #008000
# Red Shades:

# Light Red: #FFA07A
# Medium Red: #FF4500
# Dark Red: #8B0000
# Yellow Shades:

# Light Yellow: #FFFFE0
# Medium Yellow: #FFD700
# Dark Yellow: #FFA500
# Orange Shades:

# Light Orange: #FFD700
# Medium Orange: #FFA500
# Dark Orange: #FF8C00
# Purple Shades:

# Light Purple: #E6E6FA
# Medium Purple: #9370DB
# Dark Purple: #800080

# %% [markdown]
# ## Top 5 Most Common Degrees

# %%
x=df2.groupby('Degree').agg({'City':'count'}).sort_values(by='City',ascending=False).head(5)
x
# Out:
#           City
# Degree
# MBBS      3362
# MDS        873
# BDS        712
# MD         203
# BPTh/BPT   169

# %%
categories = ['MBBS', 'MDS', 'BDS', 'MD', 'BPTh/BPT']
values = [3362, 873, 712, 203, 169]

colors = ['#FF8C00', '#8A2BE2', '#008000', '#FF4500', '#6495ED']

plt.figure(figsize=(6, 5))
wedges, texts, autotexts = plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140, colors=colors,data=x)

for i, (wedge, text, autotext) in enumerate(zip(wedges, texts, autotexts)):
    autotext.set_text(f'{values[i]}')
    autotext.set_color('white')

plt.title('Top 5 Degrees', y=1.02, fontsize=12,fontweight='bold')
plt.axis('equal')
plt.savefig('Top 5 Degrees.jpg', format='jpeg')
plt.show()

# %% [markdown]
# ## Correlation between different variables

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df2.corr(), annot=True, cmap="viridis", linewidths=0.5)
plt.title('Correlation between Variables',y=1.02, fontsize=12,fontweight='bold')
plt.savefig('Correlation between Variables.jpg', format='jpeg')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14268\1096451900.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, cmap="viridis", linewidths=0.5)

# %% [markdown]
# ## Count of Doctors in different Specialties

# %%
x=df2.groupby('Speciality').agg({'City':'count'}).sort_values(by='City',ascending=False).reset_index()
x
# Out:
#                 Speciality  City
# 0                  Dentist  1601
# 1             Gynecologist   833
# 2             Pediatrician   473
# 3              Orthopedist   461
# 4   Infertility Specialist   383
# 5            Dermatologist   382
# 6          Physiotherapist   289
# 7          Ophthalmologist   254
# 8             Cardiologist   199
# 9             Psychiatrist   170
# 10               Urologist   160
# 11      Gastroenterologist   140
# 12            Neurosurgeon   136
# 13  Dietitian/Nutritionist   132
# 14             Neurologist   118
# 15           Pulmonologist   100
# 16       Bariatric Surgeon    84
# 17          Rheumatologist    49
# 18            Chiropractor     6

# %%
# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

plt.bar(x['Speciality'], x['City'], color='darkgrey')

plt.xlabel('Speciality')
plt.ylabel('Count')
plt.title('Count of Specialities (Descending Order)')
plt.xticks(rotation=30, ha='right')

for container in ax.containers:
    for bar in container:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0, f'{yval:.0f}', ha='center', va='bottom', color='black', \
                 fontsize=10)

plt.tight_layout()
plt.savefig('Count of Specialities.jpg', format='jpeg')
plt.show()

# %% [markdown]
# ## Maximun and Minimum price

# %%
x = pd.DataFrame(df2.groupby('Speciality')['consultation_fee'].agg(['max','min'])).sort_values(by=['max','min'],ascending=False)
x=x.reset_index()
x
# Out:
#                 Speciality   max  min
# 0             Neurosurgeon  5000  500
# 1          Ophthalmologist  5000  200
# 2              Neurologist  4100  500
# 3             Cardiologist  4000  500
# 4                Urologist  4000  450
# 5        Bariatric Surgeon  4000  400
# 6   Dietitian/Nutritionist  4000    0
# 7          Physiotherapist  4000    0
# 8             Psychiatrist  3850  700
# 9             Chiropractor  3000  700
# 10          Rheumatologist  3000  400
# 11           Dermatologist  3000  300
# 12            Pediatrician  3000  300
# 13             Orthopedist  3000  200
# 14            Gynecologist  3000    0
# 15  Infertility Specialist  3000    0
# 16           Pulmonologist  2500  500
# 17      Gastroenterologist  2500  350
# 18                 Dentist  2000    0

# %%
# Create a clustered column chart
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
index = range(len(x))

plt.bar(index, x['max'], bar_width, label='Max Consultation Fee', color='g', alpha=0.6)
plt.bar([i + bar_width for i in index], x['min'], bar_width, label='Min Consultation Fee', color='r', alpha=0.6)

plt.xlabel('Speciality')
plt.ylabel('Consultation Fee')
plt.title('Max and Min Consultation Fees by Speciality',y=1.02, fontsize=12,fontweight='bold')
plt.xticks([i + bar_width/2 for i in index], x['Speciality'], rotation=30, ha='right')
plt.legend()

for container in ax.containers:
    for bar in container:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 10, f'{yval:.0f}', ha='center', color='black', fontsize=8)

plt.tight_layout()
plt.savefig('consultation_fees_plot.jpg', format='jpeg')
plt.show()

# %% [markdown]
# ## Average years of experience

# %%
x = pd.DataFrame(df2.groupby('Speciality')['Year_of_experience'].agg('mean')).sort_values(by='Year_of_experience',ascending=False).reset_index()
x
# Out:
#                 Speciality  Year_of_experience
# 0        Bariatric Surgeon           24.702381
# 1             Cardiologist           24.100503
# 2             Gynecologist           22.903962
# 3              Neurologist           22.423729
# 4   Infertility Specialist           22.109661
# 5             Pediatrician           22.099366
# 6                Urologist           21.900000
# 7           Rheumatologist           21.142857
# 8              Orthopedist           21.121475
# 9             Neurosurgeon           21.029412
# 10      Gastroenterologist           20.671429
# 11         Ophthalmologist           20.188976
# 12           Pulmonologist           19.720000
# 13            Psychiatrist           16.782353
# 14                 Dentist           16.358526
# 15           Dermatologist           16.230366
# 16  Dietitian/Nutritionist           15.446970
# 17         Physiotherapist           12.204152
# 18            Chiropractor           11.500000

# %%
# Create a column chart
fig, ax = plt.subplots(figsize=(10, 6))
plt.bar(x['Speciality'], x['Year_of_experience'], color='purple')

for container in ax.containers:
    for bar in container:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval + 0, f'{yval:.0f}', ha='center', va='bottom', color='black', \
                 fontsize=10)
plt.xlabel('Speciality')
plt.ylabel('Mean Year of Experience')
plt.title('Mean Year of Experience by Speciality')
plt.xticks(rotation=30, ha='right')

plt.tight_layout()
plt.savefig('Mean Year of Experience by Speciality.jpg', format='jpeg')
plt.show()
